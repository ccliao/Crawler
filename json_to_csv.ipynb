# %%
import json
import datetime
import pandas as pd
import os

def transferdata(inpfile):
    inp = open(inpfile, encoding='utf8')
    clists = list(inp)
    inp.close()
    j=0

    for i in clists:
        #共54個欄位
        item1, item2, item3, item4, item5, item6, item7, item8, item9, item10  = [],[],[],[],[],[],[],[],[],[]
        item11, item12, item13, item14, item15, item16, item17, item18, item19, item20  = [],[],[],[],[],[],[],[],[],[]
        item21, item22, item23, item24, item25, item26, item27, item28, item29, item30  = [],[],[],[],[],[],[],[],[],[]
        item31, item32, item33, item34, item35, item36, item37, item38, item39, item40  = [],[],[],[],[],[],[],[],[],[]
        item41, item42, item43, item44, item45, item46, item47, item48, item49, item50  = [],[],[],[],[],[],[],[],[],[]
        item51, item52, item53, item54, item55  = [],[],[],[],[]

        x = json.loads(i.split(',',1)[1].strip()) #基本資料
        item1.append(str(i.split(',',1)[0])) #統一編號
        try:
            item2.append(x['公司狀況'])
        except:
            item2.append('')
        try:
            item3.append(x['公司名稱'])
        except:
            item3.append('')
        try:
            item4.append(x['資本總額(元)'])
        except:
            item4.append('')
        try:
            item5.append(x['實收資本額(元)'])
        except:
            item5.append('')
        try:
            item6.append(x['代表人姓名'])
        except:
            item6.append('')        
        try:
            item7.append(x['公司所在地'])
        except:
            item7.append('')        
        try:
            item8.append(x['登記機關'])
        except:
            item8.append('')        
        try:
            if x['核准設立日期'] is None:
                item9.append('')
            else:
                item9.append(str(datetime.date(x['核准設立日期']['year'],x['核准設立日期']['month'],x['核准設立日期']['day'])))
        except:
            item9.append('')    
        try:
            if x['最後核准變更日期'] is None:
                item10.append('')
            else:
                item10.append(str(datetime.date(x['最後核准變更日期']['year'],x['最後核准變更日期']['month'],x['最後核准變更日期']['day'])))
        except:
            item10.append('')
        try:
            item11.append(x['所營事業資料'])
        except:
            item11.append('')
        try:
            item12.append(x['董監事名單'])
        except:
            item12.append('')
        try:
            item13.append(x['經理人名單'])
        except:
            item13.append('')        
        try:
            if x['停業日期(起)'] is None:
                item14.append('')
            else:
                item14.append(str(datetime.date(x['停業日期(起)']['year'],x['停業日期(起)']['month'],x['停業日期(起)']['day'])))
        except:
            item14.append('')
        try:
            if x['停業日期(迄)'] is None:
                item15.append('')
            else:
                item15.append(str(datetime.date(x['停業日期(迄)']['year'],x['停業日期(迄)']['month'],x['停業日期(迄)']['day'])))
        except:
            item15.append('')        
        try:
            item16.append(x['股權狀況'])
        except:
            item16.append('')   
        try:
            item17.append(x['訴訟及非訴訟代理人姓名'])
        except:
            item17.append('')           
        try:
            item18.append(x['辦事處所在地'])
        except:
            item18.append('')   
        try:
            if x['核准報備日期'] is None:
                item19.append('')
            else:
                item19.append(str(datetime.date(x['核准報備日期']['year'],x['核准報備日期']['month'],x['核准報備日期']['day'])))
        except:
            item19.append('') 
        try:
            item20.append(x['代表人在中華民國境內所為之法律行為'])
        except:
            item20.append('')   
        try:
            item21.append(x['在中華民國境內營運資金'])
        except:
            item21.append('')   
        try:
            item22.append(x['分公司所在地'])
        except:
            item22.append('')   
        try:
            if x['核准認許日期'] is None:
                item23.append('')
            else:
                item23.append(str(datetime.date(x['核准認許日期']['year'],x['核准認許日期']['month'],x['核准認許日期']['day'])))
        except:
            item23.append('')          
        try:
            if x['延展開業日期(迄)'] is None:
                item24.append('')
            else:
                item24.append(str(datetime.date(x['延展開業日期(迄)']['year'],x['延展開業日期(迄)']['month'],x['延展開業日期(迄)']['day'])))
        except:
            item24.append('')          
        try:
            if x['核准許可報備日期'] is None:
                item25.append('')
            else:
                item25.append(str(datetime.date(x['核准許可報備日期']['year'],x['核准許可報備日期']['month'],x['核准許可報備日期']['day'])))
        except:
            item25.append('')           
        try:
            item26.append(x['代表人在台灣地區業務活動範圍'])
        except:
            item26.append('')           
        try:
            item27.append(x['在台灣地區營業所用'])
        except:
            item27.append('')            
        try:
            if x['核准許可日期'] is None:
                item28.append('')
            else:
                item28.append(str(datetime.date(x['核准許可日期']['year'],x['核准許可日期']['month'],x['核准許可日期']['day'])))
        except:
            item28.append('')              
#         try:
#             item29.append(x['統一編號'])
#         except:
#             item29.append('')    
        try:
            if x['最近異動日期'] is None:
                item30.append('')
            else:
                item30.append(str(datetime.date(x['最近異動日期']['year'],x['最近異動日期']['month'],x['最近異動日期']['day'])))
        except:
            item30.append('')           
        try:
            item31.append(x['商業名稱'])
        except:
            item31.append('')            
        try:
            item32.append(x['負責人姓名'])
        except:
            item32.append('')            
        try:
            item33.append(x['現況'])
        except:
            item33.append('')            
        try:
            item34.append(x['資本額(元)'])
        except:
            item34.append('')            
        try:
            item35.append(x['組織類型'])
        except:
            item35.append('')                  
        try:
            item36.append(x['地址'])
        except:
            item36.append('')            
        try:
            item37.append(x['營業項目'].replace('\r', ' '))
        except:
            item37.append('')           
        try:
            item38.append(x['合夥人姓名'])
        except:
            item38.append('')           
        try:
            item39.append(x['類型'])
        except:
            item39.append('')           
        try:
            item40.append(x['名稱'])
        except:
            item40.append('')           
        try:
            item41.append(x['資料來源'])
        except:
            item41.append('')           
        try:
            item42.append(x['類別'])
        except:
            item42.append('')           
        try:
            item43.append(x['來源'])
        except:
            item43.append('')           
        try:
            item44.append(x['分公司狀況'])
        except:
            item44.append('')           
        try:
            item45.append(x['分公司名稱'])
        except:
            item45.append('')           
        try:
            item46.append(x['分公司經理姓名'])
        except:
            item46.append('')           
        try:
            item47.append(x['總(本)公司統一編號'])
        except:
            item47.append('')          
        try:
            if x['撤銷日期'] is None:
                item48.append('')
            else:
                item48.append(str(datetime.date(x['撤銷日期']['year'],x['撤銷日期']['month'],x['撤銷日期']['day'])))
        except:
            item48.append('')          
        try:
            item49.append(x['負責姓名'])
        except:
            item49.append('')          
        try:
            if x['廢止日期'] is None:
                item50.append('')
            else:
                item50.append(str(datetime.date(x['廢止日期']['year'],x['廢止日期']['month'],x['廢止日期']['day'])))
        except:
            item50.append('')         
        try:
            item51.append(x['舊營業項目資料'])
        except:
            item51.append('')   
        try:
            item52.append(x['停業核准(備)機關'])
        except:
            item52.append('')  
        try:
            item53.append(x['公司屬性'])
        except:
            item53.append('')  
        try:
            if x['公司狀況日期'] is None:
                item54.append('')
            else:
                item54.append(str(datetime.date(x['公司狀況日期']['year'],x['公司狀況日期']['month'],x['公司狀況日期']['day'])))
        except:
            item54.append('')     
        try:
            item55.append(x['公司狀況文號'])
        except:
            item55.append('')  

        company = pd.DataFrame({
                '統一編號':item1, '公司狀況':item2, '公司名稱':item3, '資本總額(元)':item4, '實收資本額(元)':item5, '代表人姓名':item6,\
                 '公司所在地':item7, '登記機關':item8, '核准設立日期':item9, '最後核准變更日期':item10, '所營事業資料':item11, '董監事名單':item12,\
                 '經理人名單':item13, '停業日期(起)':item14, '停業日期(迄)':item15, '股權狀況':item16, '訴訟及非訴訟代理人姓名':item17, \
                '辦事處所在地':item18, '核准報備日期':item19, '代表人在中華民國境內所為之法律行為':item20, '在中華民國境內營運資金':item21, \
                '分公司所在地':item22, '核准認許日期':item23, '延展開業日期(迄)':item24, '核准許可報備日期':item25, \
                '代表人在台灣地區業務活動範圍':item26, '在台灣地區營業所用':item27, '核准許可日期':item28, '最近異動日期':item30,\
                '商業名稱':item31, '負責人姓名':item32, '現況':item33, '資本額(元)':item34, '組織類型':item35, '地址':item36, \
                '營業項目':item37, '合夥人姓名':item38, '類型':item39, '名稱':item40, '資料來源':item41, '類別':item42, '來源':item43, \
                '分公司狀況':item44, '分公司名稱':item45, '分公司經理姓名':item46, '總(本)公司統一編號':item47, '撤銷日期':item48, \
                '負責姓名':item49, '廢止日期':item50, '舊營業項目資料':item51, '停業核准(備)機關':item52, '公司屬性':item53, \
                '公司狀況日期':item54, '公司狀況文號':item55
            })
        savefilename = inpfile.strip('.json')+'.csv'
        if not os.path.isfile(savefilename):
            company.to_csv(savefilename)
        else:
            company.to_csv(savefilename, mode='a', header=False)
        j+=1
        if (j % 10000 == 0):
            print (str(j)+'Finished')
    print (savefilename+' Finished')
    inp.close()
    
if __name__ == '__main__':
    filenames = ['00000000.json','10000000.json','20000000.json','30000000.json','40000000.json','50000000.json',
                 '60000000.json','70000000.json','80000000.json','90000000.json','bussiness-00000000.json','bussiness-10000000.json',
            'bussiness-20000000.json','bussiness-30000000.json','bussiness-40000000.json','bussiness-50000000.json',
            'bussiness-60000000.json','bussiness-70000000.json','bussiness-80000000.json','bussiness-90000000.json']
   
    for inpfile in filenames:
        transferdata(inpfile)
# Out:
# 10000Finished
# 20000Finished
# 30000Finished
# 40000Finished
# 50000Finished
# 00000000.csv Finished
# 10000Finished
# 20000Finished
# 30000Finished
# 40000Finished
# 50000Finished
# 60000Finished
# 70000Finished
# 80000Finished
# 90000Finished
# 100000Finished
# 110000Finished
# 120000Finished
# 130000Finished
# 140000Finished
# 150000Finished
# 160000Finished
# 170000Finished
# 180000Finished
# 190000Finished
# 10000000.csv Finished
# 10000Finished
# 20000Finished
# 30000Finished
# 40000Finished
# 50000Finished
# 60000Finished
# 70000Finished
# 80000Finished
# 90000Finished
# 100000Finished
# 110000Finished
# 120000Finished
# 130000Finished
# 140000Finished
# 150000Finished
# 160000Finished
# 170000Finished
# 180000Finished
# 190000Finished
# 200000Finished
# 210000Finished
# 220000Finished
# 230000Finished
# 240000Finished
# 250000Finished
# 260000Finished
# 270000Finished
# 280000Finished
# 290000Finished
# 300000Finished
# 310000Finished
# 320000Finished
# 330000Finished
# ...

# %%
filenames = ['bussiness-80000000.json']
inp = open(inpfile, encoding='utf8')
clists = list(inp)
